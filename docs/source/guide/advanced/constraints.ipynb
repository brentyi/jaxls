# %% [markdown]
# # Constraints
#
# How to handle constraints in nonlinear least squares problems using jaxls.
# This guide covers equality and inequality constraints, with a portfolio optimization example.
#
# Features used:
# - {func}`@jaxls.Cost.factory <jaxls.Cost.factory>` with `kind` parameter for constraints
# - {class}`~jaxls.AugmentedLagrangianConfig` for solver tuning

# %%
import sys
from loguru import logger

logger.remove()
logger.add(sys.stdout, format="<level>{level: <8}</level> | {message}");

# %%
import jax
import jax.numpy as jnp
import jaxls

# %% [markdown]
# ## Types of constraints
#
# jaxls supports three constraint types, specified via the `kind` parameter in `@jaxls.Cost.factory`:
#
# | Constraint Type | `kind` Parameter | Mathematical Form |
# |----------------|------------------|-------------------|
# | Equality | `"constraint_eq_zero"` | $h(x) = 0$ |
# | Inequality (upper bound) | `"constraint_leq_zero"` | $g(x) \leq 0$ |
# | Inequality (lower bound) | `"constraint_geq_zero"` | $g(x) \geq 0$ |
#
# The default `kind="l2_squared"` creates a standard least-squares cost term.

# %% [markdown]
# ## Example: portfolio optimization
#
# We'll optimize a portfolio of 4 assets to minimize variance (risk) subject to:
# - Budget constraint: weights sum to 1 (equality)
# - Return target: expected return >= minimum threshold (inequality)
# - No short-selling: all weights >= 0 (inequality)

# %%
# Asset data: 4 assets with expected returns and covariance.
n_assets = 4
asset_names = ["Tech", "Healthcare", "Energy", "Bonds"]

# Expected annual returns.
expected_returns = jnp.array([0.12, 0.08, 0.10, 0.04])

# Covariance matrix (annual).
covariance = jnp.array(
    [
        [0.04, 0.006, 0.010, -0.002],
        [0.006, 0.025, 0.004, 0.001],
        [0.010, 0.004, 0.035, -0.001],
        [-0.002, 0.001, -0.001, 0.005],
    ]
)

print(
    "Expected returns:", {n: f"{r:.1%}" for n, r in zip(asset_names, expected_returns)}
)
# Out:
# Expected returns: {'Tech': '12.0%', 'Healthcare': '8.0%', 'Energy': '10.0%', 'Bonds': '4.0%'}

# %%
# Define the portfolio weights variable.
class WeightsVar(
    jaxls.Var[jax.Array], default_factory=lambda: jnp.ones(n_assets) / n_assets
):
    """Portfolio weights (n_assets-dimensional vector)."""


weights_var = WeightsVar(id=0)

# %% [markdown]
# ## Defining costs and constraints
#
# ### Objective: minimize variance
#
# Portfolio variance is $w^T \Sigma w$. We use the Cholesky factor $L$ where $\Sigma = LL^T$,
# so minimizing $\|L^T w\|^2$ is equivalent to minimizing variance.

# %%
# Cholesky decomposition for the variance cost.
cov_chol = jnp.linalg.cholesky(covariance)


@jaxls.Cost.factory  # Default kind="l2_squared".
def variance_cost(
    vals: jaxls.VarValues, var: WeightsVar, cov_chol: jax.Array
) -> jax.Array:
    """Minimize portfolio variance: ||L.T @ w||^2 = w.T @ cov @ w."""
    return cov_chol.T @ vals[var]

# %% [markdown]
# ### Budget constraint (equality)
#
# The weights must sum to 1 (fully invested portfolio): $\sum_i w_i = 1$
#
# We write this as $h(w) = \sum_i w_i - 1 = 0$.

# %%
@jaxls.Cost.factory(kind="constraint_eq_zero")
def budget_constraint(vals: jaxls.VarValues, var: WeightsVar) -> jax.Array:
    """Weights must sum to 1 (fully invested)."""
    weights = vals[var]
    return jnp.array([jnp.sum(weights) - 1.0])

# %% [markdown]
# ### Return target (inequality >= 0)
#
# Expected portfolio return must meet a minimum target: $w^T \mu \geq r_{\text{target}}$
#
# We write this as $g(w) = w^T \mu - r_{\text{target}} \geq 0$.

# %%
@jaxls.Cost.factory(kind="constraint_geq_zero")
def return_constraint(
    vals: jaxls.VarValues, var: WeightsVar, exp_ret: jax.Array, target: float
) -> jax.Array:
    """Expected return must meet target: E[r] >= target."""
    weights = vals[var]
    return jnp.array([jnp.dot(weights, exp_ret) - target])

# %% [markdown]
# ### No short-selling (inequality >= 0)
#
# All weights must be non-negative: $w_i \geq 0$ for all $i$
#
# This returns the weights directly as the constraint output.

# %%
@jaxls.Cost.factory(kind="constraint_geq_zero")
def no_short_selling(vals: jaxls.VarValues, var: WeightsVar) -> jax.Array:
    """No short-selling: weights >= 0."""
    return vals[var]

# %% [markdown]
# ## Solving the problem
#
# We'll solve for a target return of 8% (between the lowest-return Bonds at 4% and highest-return Tech at 12%).

# %%
target_return = 0.08

costs = [
    variance_cost(weights_var, cov_chol),
    budget_constraint(weights_var),
    return_constraint(weights_var, expected_returns, target_return),
    no_short_selling(weights_var),
]

# Build problem (before .analyze() to visualize the problem structure structure).
unanalyzed_problem = jaxls.LeastSquaresProblem(costs, [weights_var])

# Visualize problem structure structure showing costs, constraints, and variables.
unanalyzed_problem.show()
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Analyze and solve the problem.
problem = unanalyzed_problem.analyze()
solution = problem.solve(
    linear_solver="dense_cholesky",
    termination=jaxls.TerminationConfig(cost_tolerance=1e-8),
)
# Out:
# INFO     | Building optimization problem with 4 terms and 1 variables: 1 costs, 1 eq_zero, 0 leq_zero, 2 geq_zero
# INFO     | Vectorizing constraint group with 1 constraints (constraint_eq_zero), 1 variables each: augmented_budget_constraint
# INFO     | Vectorizing group with 1 costs, 1 variables each: variance_cost
# INFO     | Vectorizing constraint group with 1 constraints (constraint_geq_zero), 1 variables each: augmented_return_constraint
# INFO     | Vectorizing constraint group with 1 constraints (constraint_geq_zero), 1 variables each: augmented_no_short_selling
# INFO     | Augmented Lagrangian: initial snorm=0.0000e+00, csupn=0.0000e+00, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0088 lambd=0.0005
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00881 (avg 0.00220)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #1: cost=0.0088 lambd=0.0010
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00881 (avg 0.00220)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #2: cost=0.0088 lambd=0.0020
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00881 (avg 0.00220)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.50e-02 cost_prev=0.0088 cost_new=0.0085
# INFO     |  step #3: cost=0.0036 lambd=0.0010
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00356 (avg 0.00089)
# INFO     |      - augmented_return_constraint(1): 0.00498 (avg 0.00498)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.96e-02 cost_prev=0.0085 cost_new=0.0057
# INFO     |  step #4: cost=0.0049 lambd=0.0005
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00489 (avg 0.00122)
# INFO     |      - augmented_return_constraint(1): 0.00086 (avg 0.00086)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.86e-04 cost_prev=0.0057 cost_new=0.0057
# INFO     |  AL update: snorm=9.0866e-03, csupn=9.0866e-03, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0049 lambd=0.0003
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00492 (avg 0.00123)
# INFO     |      - augmented_return_constraint(1): 0.00516 (avg 0.00516)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=6.70e-02 cost_prev=0.0101 cost_new=0.0072
# INFO     |  step #6: cost=0.0067 lambd=0.0001
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00673 (avg 0.00168)
# INFO     |      - augmented_return_constraint(1): 0.00048 (avg 0.00048)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.89e-05 cost_prev=0.0072 cost_new=0.0072
# INFO     |  AL update: snorm=1.1763e-03, csupn=1.1763e-03, max_rho=4.0000e+01
# INFO     |  step #7: cost=0.0067 lambd=0.0001
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00673 (avg 0.00168)
# INFO     |      - augmented_return_constraint(1): 0.00086 (avg 0.00086)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.86e-03 cost_prev=0.0076 cost_new=0.0075
# INFO     |  AL update: snorm=1.5295e-04, csupn=1.5295e-04, max_rho=4.0000e+01
# INFO     |  step #8: cost=0.0070 lambd=0.0000
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00702 (avg 0.00175)
# INFO     |      - augmented_return_constraint(1): 0.00056 (avg 0.00056)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=6.39e-04 cost_prev=0.0076 cost_new=0.0076
# INFO     |  AL update: snorm=1.9588e-05, csupn=1.9588e-05, max_rho=4.0000e+01
# INFO     |  step #9: cost=0.0071 lambd=0.0000
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - variance_cost(1): 0.00706 (avg 0.00176)
# INFO     |      - augmented_return_constraint(1): 0.00053 (avg 0.00053)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=7.02e-05 cost_prev=0.0076 cost_new=0.0076
# INFO     |  AL update: snorm=2.5183e-06, csupn=2.5183e-06, max_rho=4.0000e+01
# INFO     | Terminated @ iteration #10: cost=0.0071 criteria=[0 1 0], term_deltas=7.0e-04,5.4e-05,6.0e-04

# %%
# Extract results.
optimal_weights = solution[weights_var]

print("\nOptimal allocation:")
for name, w in zip(asset_names, optimal_weights):
    print(f"  {name}: {float(w):.1%}")

portfolio_return = float(jnp.dot(optimal_weights, expected_returns))
portfolio_std = float(jnp.sqrt(optimal_weights @ covariance @ optimal_weights))

print("\nPortfolio metrics:")
print(f"  Expected return: {portfolio_return:.2%}")
print(f"  Std deviation: {portfolio_std:.2%}")
print(f"  Weights sum: {float(jnp.sum(optimal_weights)):.6f}")
# Out:
# Optimal allocation:
#   Tech: 26.4%
#   Healthcare: 17.3%
#   Energy: 20.0%
#   Bonds: 36.4%
#
# Portfolio metrics:
#   Expected return: 8.00%
#   Std deviation: 8.40%
#   Weights sum: 1.000000

# %% [markdown]
# ## Efficient frontier
#
# By varying the target return, we can trace out the efficient frontier.
# Using `jax.lax.scan`, we solve sequentially while using each solution as the
# initial guess for the next (warm-starting).

# %%
# Range of target returns.
min_return = float(expected_returns.min())
max_return = float(expected_returns.max())
target_returns = jnp.linspace(min_return + 0.005, max_return - 0.005, 15)


def solve_for_target(
    current_vals: jaxls.VarValues, target: jax.Array
) -> tuple[jaxls.VarValues, jax.Array]:
    """Solve portfolio optimization for a given target return.

    Args:
        current_vals: Solution from previous target (used as initial guess).
        target: Target return for this solve.

    Returns:
        Tuple of (solution values, optimal weights).
    """
    costs = [
        variance_cost(weights_var, cov_chol),
        budget_constraint(weights_var),
        return_constraint(weights_var, expected_returns, target),
        no_short_selling(weights_var),
    ]
    problem = jaxls.LeastSquaresProblem(costs, [weights_var]).analyze()
    solution = problem.solve(
        current_vals,
        linear_solver="dense_cholesky",
        termination=jaxls.TerminationConfig(cost_tolerance=1e-8),
    )
    return solution, solution[weights_var]


# Solve sequentially with warm-starting.
initial_vals = jaxls.VarValues.make([weights_var])
_, all_weights = jax.lax.scan(solve_for_target, initial_vals, target_returns)
returns_achieved = jax.vmap(lambda w: jnp.dot(w, expected_returns))(all_weights)
std_devs = jax.vmap(lambda w: jnp.sqrt(w @ covariance @ w))(all_weights)

print(f"Computed {len(target_returns)} points on the efficient frontier")
# Out:
# INFO     | Building optimization problem with 4 terms and 1 variables: 1 costs, 1 eq_zero, 0 leq_zero, 2 geq_zero
# INFO     | Vectorizing group with 1 costs, 1 variables each: variance_cost
# INFO     | Vectorizing constraint group with 1 constraints (constraint_geq_zero), 1 variables each: augmented_return_constraint
# INFO     | Vectorizing constraint group with 1 constraints (constraint_eq_zero), 1 variables each: augmented_budget_constraint
# INFO     | Vectorizing constraint group with 1 constraints (constraint_geq_zero), 1 variables each: augmented_no_short_selling
# INFO     | Augmented Lagrangian: initial snorm=0.0000e+00, csupn=0.0000e+00, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0088 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00881 (avg 0.00220)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.50e-02 cost_prev=0.0088 cost_new=0.0035
# INFO     |  step #1: cost=0.0035 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.25e-04 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=3.5298e-04, csupn=3.5298e-04, max_rho=4.0000e+01
# INFO     |  step #2: cost=0.0035 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.50e-02 cost_prev=0.0035 cost_new=0.0035
# INFO     |  step #3: cost=0.0035 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.14e-06 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=0.0000e+00, csupn=0.0000e+00, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0035 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=1.18e-06 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=0.0000e+00, csupn=0.0000e+00, max_rho=4.0000e+01
# INFO     | Terminated @ iteration #5: cost=0.0035 criteria=[0 0 1], term_deltas=6.6e-08,6.0e-07,1.8e-08
# INFO     | Augmented Lagrangian: initial snorm=0.0000e+00, csupn=0.0000e+00, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0035 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.75e-03 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=3.5274e-04, csupn=3.5274e-04, max_rho=4.0000e+01
# INFO     |  step #1: cost=0.0035 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.50e-02 cost_prev=0.0035 cost_new=0.0035
# INFO     |  step #2: cost=0.0035 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.78e-06 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=1.1921e-07, csupn=1.1921e-07, max_rho=4.0000e+01
# INFO     |  step #3: cost=0.0035 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=1.89e-05 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=1.1921e-07, csupn=1.1921e-07, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #4: cost=0.0035 criteria=[0 0 1], term_deltas=4.0e-07,9.5e-06,2.0e-07
# INFO     | Augmented Lagrangian: initial snorm=1.1921e-07, csupn=1.1921e-07, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0035 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.75e-03 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=3.5274e-04, csupn=3.5274e-04, max_rho=4.0000e+01
# INFO     |  step #1: cost=0.0035 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.50e-02 cost_prev=0.0035 cost_new=0.0035
# INFO     |  step #2: cost=0.0035 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.13e-06 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=5.9605e-08, csupn=5.9605e-08, max_rho=4.0000e+01
# INFO     |  step #3: cost=0.0035 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=7.09e-06 cost_prev=0.0035 cost_new=0.0035
# INFO     |  AL update: snorm=5.9605e-08, csupn=5.9605e-08, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #4: cost=0.0035 criteria=[0 0 1], term_deltas=1.3e-07,3.6e-06,8.4e-08
# INFO     | Augmented Lagrangian: initial snorm=4.3689e-03, csupn=4.3689e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0035 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00353 (avg 0.00088)
# INFO     |      - augmented_return_constraint(1): 0.00019 (avg 0.00019)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.24e-03 cost_prev=0.0037 cost_new=0.0036
# INFO     |  AL update: snorm=1.6532e-03, csupn=1.6532e-03, max_rho=4.0000e+01
# INFO     |  step #1: cost=0.0036 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00357 (avg 0.00089)
# INFO     |      - augmented_return_constraint(1): 0.00011 (avg 0.00011)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.93e-02 cost_prev=0.0037 cost_new=0.0037
# INFO     |  step #2: cost=0.0036 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00361 (avg 0.00090)
# INFO     |      - augmented_return_constraint(1): 0.00005 (avg 0.00005)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.10e-06 cost_prev=0.0037 cost_new=0.0037
# INFO     |  AL update: snorm=5.9254e-04, csupn=5.9254e-04, max_rho=4.0000e+01
# INFO     |  step #3: cost=0.0036 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00361 (avg 0.00090)
# INFO     |      - augmented_return_constraint(1): 0.00008 (avg 0.00008)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=6.14e-04 cost_prev=0.0037 cost_new=0.0037
# INFO     |  AL update: snorm=2.2139e-04, csupn=2.2139e-04, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0036 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00363 (avg 0.00091)
# INFO     |      - augmented_return_constraint(1): 0.00007 (avg 0.00007)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.53e-04 cost_prev=0.0037 cost_new=0.0037
# INFO     |  AL update: snorm=8.2351e-05, csupn=8.2351e-05, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0036 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00364 (avg 0.00091)
# INFO     |      - augmented_return_constraint(1): 0.00007 (avg 0.00007)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=7.14e-05 cost_prev=0.0037 cost_new=0.0037
# INFO     |  AL update: snorm=3.0689e-05, csupn=3.0689e-05, max_rho=4.0000e+01
# INFO     |  step #6: cost=0.0036 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00364 (avg 0.00091)
# INFO     |      - augmented_return_constraint(1): 0.00007 (avg 0.00007)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.80e-05 cost_prev=0.0037 cost_new=0.0037
# INFO     |  AL update: snorm=1.1440e-05, csupn=1.1440e-05, max_rho=1.6000e+02
# INFO     |  step #7: cost=0.0036 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00364 (avg 0.00091)
# INFO     |      - augmented_return_constraint(1): 0.00007 (avg 0.00007)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=7.74e-05 cost_prev=0.0037 cost_new=0.0037
# INFO     |  AL update: snorm=4.2692e-06, csupn=4.2692e-06, max_rho=1.6000e+02
# INFO     |  step #8: cost=0.0036 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00364 (avg 0.00091)
# INFO     |      - augmented_return_constraint(1): 0.00007 (avg 0.00007)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #9: cost=0.0036 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00364 (avg 0.00091)
# INFO     |      - augmented_return_constraint(1): 0.00007 (avg 0.00007)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=9.00e-06 cost_prev=0.0037 cost_new=0.0037
# INFO     |  AL update: snorm=4.2692e-06, csupn=4.2692e-06, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #10: cost=0.0036 criteria=[0 1 0], term_deltas=3.8e-05,6.1e-06,6.9e-05
# INFO     | Augmented Lagrangian: initial snorm=5.0043e-03, csupn=5.0043e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0036 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00364 (avg 0.00091)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.77e-03 cost_prev=0.0039 cost_new=0.0039
# INFO     |  AL update: snorm=3.5075e-03, csupn=3.5075e-03, max_rho=4.0000e+01
# INFO     |  step #1: cost=0.0037 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00373 (avg 0.00093)
# INFO     |      - augmented_return_constraint(1): 0.00077 (avg 0.00077)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.63e-02 cost_prev=0.0045 cost_new=0.0041
# INFO     |  step #2: cost=0.0040 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00400 (avg 0.00100)
# INFO     |      - augmented_return_constraint(1): 0.00007 (avg 0.00007)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.14e-05 cost_prev=0.0041 cost_new=0.0041
# INFO     |  AL update: snorm=4.4918e-04, csupn=4.4918e-04, max_rho=4.0000e+01
# INFO     |  step #3: cost=0.0040 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00400 (avg 0.00100)
# INFO     |      - augmented_return_constraint(1): 0.00013 (avg 0.00013)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.87e-03 cost_prev=0.0041 cost_new=0.0041
# INFO     |  AL update: snorm=5.8413e-05, csupn=5.8413e-05, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0040 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00404 (avg 0.00101)
# INFO     |      - augmented_return_constraint(1): 0.00008 (avg 0.00008)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.33e-04 cost_prev=0.0041 cost_new=0.0041
# INFO     |  AL update: snorm=7.4729e-06, csupn=7.4729e-06, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0041 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00405 (avg 0.00101)
# INFO     |      - augmented_return_constraint(1): 0.00008 (avg 0.00008)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.69e-05 cost_prev=0.0041 cost_new=0.0041
# INFO     |  AL update: snorm=9.6112e-07, csupn=9.6112e-07, max_rho=4.0000e+01
# INFO     |  step #6: cost=0.0041 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00405 (avg 0.00101)
# INFO     |      - augmented_return_constraint(1): 0.00008 (avg 0.00008)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.57e-05 cost_prev=0.0041 cost_new=0.0041
# INFO     |  AL update: snorm=1.2666e-07, csupn=1.2666e-07, max_rho=1.6000e+02
# INFO     |  step #7: cost=0.0041 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00405 (avg 0.00101)
# INFO     |      - augmented_return_constraint(1): 0.00008 (avg 0.00008)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.99e-05 cost_prev=0.0041 cost_new=0.0041
# INFO     |  AL update: snorm=1.4901e-08, csupn=1.4901e-08, max_rho=1.6000e+02
# INFO     |  step #8: cost=0.0041 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00405 (avg 0.00101)
# INFO     |      - augmented_return_constraint(1): 0.00008 (avg 0.00008)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=3.53e-06 cost_prev=0.0041 cost_new=0.0041
# INFO     |  AL update: snorm=1.4901e-08, csupn=1.4901e-08, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #9: cost=0.0041 criteria=[0 0 1], term_deltas=2.3e-07,1.8e-06,3.8e-07
# INFO     | Augmented Lagrangian: initial snorm=5.0000e-03, csupn=5.0000e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0041 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00405 (avg 0.00101)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.31e-03 cost_prev=0.0043 cost_new=0.0043
# INFO     |  AL update: snorm=5.3576e-03, csupn=5.3576e-03, max_rho=4.0000e+01
# INFO     |  step #1: cost=0.0040 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00401 (avg 0.00100)
# INFO     |      - augmented_return_constraint(1): 0.00179 (avg 0.00179)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.30e-02 cost_prev=0.0058 cost_new=0.0048
# INFO     |  step #2: cost=0.0046 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00464 (avg 0.00116)
# INFO     |      - augmented_return_constraint(1): 0.00017 (avg 0.00017)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.73e-05 cost_prev=0.0048 cost_new=0.0048
# INFO     |  AL update: snorm=6.9366e-04, csupn=6.9366e-04, max_rho=1.6000e+02
# INFO     |  step #3: cost=0.0046 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00464 (avg 0.00116)
# INFO     |      - augmented_return_constraint(1): 0.00030 (avg 0.00030)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=9.69e-03 cost_prev=0.0049 cost_new=0.0049
# INFO     |  AL update: snorm=9.0219e-05, csupn=9.0219e-05, max_rho=1.6000e+02
# INFO     |  step #4: cost=0.0047 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00474 (avg 0.00119)
# INFO     |      - augmented_return_constraint(1): 0.00020 (avg 0.00020)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.43e-04 cost_prev=0.0049 cost_new=0.0049
# INFO     |  AL update: snorm=1.1526e-05, csupn=1.1526e-05, max_rho=1.6000e+02
# INFO     |  step #5: cost=0.0048 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00476 (avg 0.00119)
# INFO     |      - augmented_return_constraint(1): 0.00018 (avg 0.00018)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.51e-05 cost_prev=0.0049 cost_new=0.0049
# INFO     |  AL update: snorm=1.4827e-06, csupn=1.4827e-06, max_rho=1.6000e+02
# INFO     |  step #6: cost=0.0048 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00476 (avg 0.00119)
# INFO     |      - augmented_return_constraint(1): 0.00018 (avg 0.00018)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #7: cost=0.0048 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00476 (avg 0.00119)
# INFO     |      - augmented_return_constraint(1): 0.00018 (avg 0.00018)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #8: cost=0.0048 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00476 (avg 0.00119)
# INFO     |      - augmented_return_constraint(1): 0.00018 (avg 0.00018)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #9: cost=0.0048 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00476 (avg 0.00119)
# INFO     |      - augmented_return_constraint(1): 0.00018 (avg 0.00018)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=1.50e-05 cost_prev=0.0049 cost_new=0.0049
# INFO     |  AL update: snorm=1.4827e-06, csupn=1.4827e-06, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #10: cost=0.0048 criteria=[0 1 0], term_deltas=4.6e-05,9.7e-06,4.0e-05
# INFO     | Augmented Lagrangian: initial snorm=5.0015e-03, csupn=5.0015e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0048 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00476 (avg 0.00119)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.13e-03 cost_prev=0.0050 cost_new=0.0049
# INFO     |  AL update: snorm=7.2077e-03, csupn=7.2077e-03, max_rho=4.0000e+01
# INFO     |  step #1: cost=0.0044 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00441 (avg 0.00110)
# INFO     |      - augmented_return_constraint(1): 0.00325 (avg 0.00325)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.99e-02 cost_prev=0.0077 cost_new=0.0058
# INFO     |  step #2: cost=0.0055 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00555 (avg 0.00139)
# INFO     |      - augmented_return_constraint(1): 0.00030 (avg 0.00030)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.52e-05 cost_prev=0.0058 cost_new=0.0058
# INFO     |  AL update: snorm=9.3812e-04, csupn=9.3812e-04, max_rho=1.6000e+02
# INFO     |  step #3: cost=0.0055 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00555 (avg 0.00139)
# INFO     |      - augmented_return_constraint(1): 0.00054 (avg 0.00054)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.31e-02 cost_prev=0.0061 cost_new=0.0061
# INFO     |  step #4: cost=0.0057 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00573 (avg 0.00143)
# INFO     |      - augmented_return_constraint(1): 0.00033 (avg 0.00033)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #5: cost=0.0057 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00573 (avg 0.00143)
# INFO     |      - augmented_return_constraint(1): 0.00033 (avg 0.00033)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #6: cost=0.0057 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00573 (avg 0.00143)
# INFO     |      - augmented_return_constraint(1): 0.00033 (avg 0.00033)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #7: cost=0.0057 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00573 (avg 0.00143)
# INFO     |      - augmented_return_constraint(1): 0.00033 (avg 0.00033)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #8: cost=0.0057 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00573 (avg 0.00143)
# INFO     |      - augmented_return_constraint(1): 0.00033 (avg 0.00033)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #9: cost=0.0057 lambd=0.0010
# INFO     |      - variance_cost(1): 0.00573 (avg 0.00143)
# INFO     |      - augmented_return_constraint(1): 0.00033 (avg 0.00033)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=2.90e-05 cost_prev=0.0061 cost_new=0.0061
# INFO     |  AL update: snorm=1.2202e-04, csupn=1.2202e-04, max_rho=1.6000e+02
# INFO     |  step #10: cost=0.0057 lambd=0.0010
# INFO     |      - variance_cost(1): 0.00573 (avg 0.00143)
# INFO     |      - augmented_return_constraint(1): 0.00036 (avg 0.00036)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.61e-04 cost_prev=0.0061 cost_new=0.0061
# INFO     |  AL update: snorm=1.6078e-05, csupn=1.6078e-05, max_rho=1.6000e+02
# INFO     |  step #11: cost=0.0058 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00576 (avg 0.00144)
# INFO     |      - augmented_return_constraint(1): 0.00034 (avg 0.00034)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.13e-04 cost_prev=0.0061 cost_new=0.0061
# INFO     |  AL update: snorm=1.6168e-06, csupn=1.6168e-06, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #12: cost=0.0058 criteria=[0 1 0], term_deltas=5.8e-04,7.9e-05,5.0e-04
# INFO     | Augmented Lagrangian: initial snorm=5.0016e-03, csupn=5.0016e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0058 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00576 (avg 0.00144)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.14e-03 cost_prev=0.0060 cost_new=0.0057
# INFO     |  AL update: snorm=9.0577e-03, csupn=9.0577e-03, max_rho=4.0000e+01
# INFO     |  step #1: cost=0.0049 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00492 (avg 0.00123)
# INFO     |      - augmented_return_constraint(1): 0.00513 (avg 0.00513)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=6.70e-02 cost_prev=0.0101 cost_new=0.0072
# INFO     |  step #2: cost=0.0067 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00672 (avg 0.00168)
# INFO     |      - augmented_return_constraint(1): 0.00048 (avg 0.00048)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.05e-05 cost_prev=0.0072 cost_new=0.0072
# INFO     |  AL update: snorm=1.1826e-03, csupn=1.1826e-03, max_rho=4.0000e+01
# INFO     |  step #3: cost=0.0067 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00673 (avg 0.00168)
# INFO     |      - augmented_return_constraint(1): 0.00086 (avg 0.00086)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.86e-03 cost_prev=0.0076 cost_new=0.0075
# INFO     |  AL update: snorm=1.5378e-04, csupn=1.5378e-04, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0070 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00702 (avg 0.00175)
# INFO     |      - augmented_return_constraint(1): 0.00056 (avg 0.00056)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=6.30e-04 cost_prev=0.0076 cost_new=0.0076
# INFO     |  AL update: snorm=1.9684e-05, csupn=1.9684e-05, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0071 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00706 (avg 0.00176)
# INFO     |      - augmented_return_constraint(1): 0.00053 (avg 0.00053)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=9.81e-05 cost_prev=0.0076 cost_new=0.0076
# INFO     |  AL update: snorm=2.5332e-06, csupn=2.5332e-06, max_rho=4.0000e+01
# INFO     |  step #6: cost=0.0071 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00706 (avg 0.00177)
# INFO     |      - augmented_return_constraint(1): 0.00053 (avg 0.00053)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.48e-06 cost_prev=0.0076 cost_new=0.0076
# INFO     |  AL update: snorm=3.2783e-07, csupn=3.2783e-07, max_rho=4.0000e+01
# INFO     |  step #7: cost=0.0071 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00706 (avg 0.00177)
# INFO     |      - augmented_return_constraint(1): 0.00053 (avg 0.00053)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #8: cost=0.0071 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00706 (avg 0.00177)
# INFO     |      - augmented_return_constraint(1): 0.00053 (avg 0.00053)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #9: cost=0.0071 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00706 (avg 0.00177)
# INFO     |      - augmented_return_constraint(1): 0.00053 (avg 0.00053)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=2.94e-06 cost_prev=0.0076 cost_new=0.0076
# INFO     |  AL update: snorm=3.2783e-07, csupn=3.2783e-07, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #10: cost=0.0071 criteria=[0 1 0], term_deltas=1.2e-05,2.0e-06,9.9e-06
# INFO     | Augmented Lagrangian: initial snorm=5.0003e-03, csupn=5.0003e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0071 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00706 (avg 0.00177)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.12e-02 cost_prev=0.0073 cost_new=0.0067
# INFO     |  step #1: cost=0.0056 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00556 (avg 0.00139)
# INFO     |      - augmented_return_constraint(1): 0.00119 (avg 0.00119)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.34e-05 cost_prev=0.0067 cost_new=0.0067
# INFO     |  AL update: snorm=1.0948e-02, csupn=1.0948e-02, max_rho=4.0000e+01
# INFO     |  step #2: cost=0.0055 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00555 (avg 0.00139)
# INFO     |      - augmented_return_constraint(1): 0.00749 (avg 0.00749)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=7.42e-02 cost_prev=0.0130 cost_new=0.0089
# INFO     |  step #3: cost=0.0082 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00817 (avg 0.00204)
# INFO     |      - augmented_return_constraint(1): 0.00069 (avg 0.00069)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.86e-05 cost_prev=0.0089 cost_new=0.0089
# INFO     |  AL update: snorm=1.4184e-03, csupn=1.4184e-03, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0082 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00817 (avg 0.00204)
# INFO     |      - augmented_return_constraint(1): 0.00124 (avg 0.00124)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.86e-03 cost_prev=0.0094 cost_new=0.0093
# INFO     |  AL update: snorm=1.8428e-04, csupn=1.8428e-04, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0086 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00859 (avg 0.00215)
# INFO     |      - augmented_return_constraint(1): 0.00082 (avg 0.00082)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=7.64e-04 cost_prev=0.0094 cost_new=0.0094
# INFO     |  AL update: snorm=2.3752e-05, csupn=2.3752e-05, max_rho=4.0000e+01
# INFO     |  step #6: cost=0.0087 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00865 (avg 0.00216)
# INFO     |      - augmented_return_constraint(1): 0.00077 (avg 0.00077)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.60e-05 cost_prev=0.0094 cost_new=0.0094
# INFO     |  AL update: snorm=3.0696e-06, csupn=3.0696e-06, max_rho=4.0000e+01
# INFO     |  step #7: cost=0.0087 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00866 (avg 0.00216)
# INFO     |      - augmented_return_constraint(1): 0.00076 (avg 0.00076)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #8: cost=0.0087 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00866 (avg 0.00216)
# INFO     |      - augmented_return_constraint(1): 0.00076 (avg 0.00076)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #9: cost=0.0087 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00866 (avg 0.00216)
# INFO     |      - augmented_return_constraint(1): 0.00076 (avg 0.00076)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=3.59e-05 cost_prev=0.0094 cost_new=0.0094
# INFO     |  AL update: snorm=3.0696e-06, csupn=3.0696e-06, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #10: cost=0.0087 criteria=[0 1 0], term_deltas=1.1e-04,2.3e-05,9.6e-05
# INFO     | Augmented Lagrangian: initial snorm=5.0031e-03, csupn=5.0031e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0087 lambd=0.0005
# INFO     |      - variance_cost(1): 0.00866 (avg 0.00216)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.42e-02 cost_prev=0.0089 cost_new=0.0079
# INFO     |  step #1: cost=0.0063 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00630 (avg 0.00158)
# INFO     |      - augmented_return_constraint(1): 0.00163 (avg 0.00163)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.70e-05 cost_prev=0.0079 cost_new=0.0079
# INFO     |  AL update: snorm=1.2810e-02, csupn=1.2810e-02, max_rho=4.0000e+01
# INFO     |  step #2: cost=0.0063 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00629 (avg 0.00157)
# INFO     |      - augmented_return_constraint(1): 0.01026 (avg 0.01026)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.15e-02 cost_prev=0.0166 cost_new=0.0108
# INFO     |  step #3: cost=0.0099 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00989 (avg 0.00247)
# INFO     |      - augmented_return_constraint(1): 0.00095 (avg 0.00095)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.06e-05 cost_prev=0.0108 cost_new=0.0108
# INFO     |  AL update: snorm=1.6602e-03, csupn=1.6602e-03, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0099 lambd=0.0000
# INFO     |      - variance_cost(1): 0.00989 (avg 0.00247)
# INFO     |      - augmented_return_constraint(1): 0.00170 (avg 0.00170)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=6.84e-03 cost_prev=0.0116 cost_new=0.0115
# INFO     |  AL update: snorm=2.1569e-04, csupn=2.1569e-04, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0105 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01047 (avg 0.00262)
# INFO     |      - augmented_return_constraint(1): 0.00112 (avg 0.00112)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=9.12e-04 cost_prev=0.0116 cost_new=0.0116
# INFO     |  AL update: snorm=2.7798e-05, csupn=2.7798e-05, max_rho=4.0000e+01
# INFO     |  step #6: cost=0.0105 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01054 (avg 0.00264)
# INFO     |      - augmented_return_constraint(1): 0.00105 (avg 0.00105)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.05e-04 cost_prev=0.0116 cost_new=0.0116
# INFO     |  AL update: snorm=3.5912e-06, csupn=3.5912e-06, max_rho=4.0000e+01
# INFO     |  step #7: cost=0.0106 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01055 (avg 0.00264)
# INFO     |      - augmented_return_constraint(1): 0.00105 (avg 0.00105)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #8: cost=0.0106 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01055 (avg 0.00264)
# INFO     |      - augmented_return_constraint(1): 0.00105 (avg 0.00105)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #9: cost=0.0106 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01055 (avg 0.00264)
# INFO     |      - augmented_return_constraint(1): 0.00105 (avg 0.00105)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.56e-05 cost_prev=0.0116 cost_new=0.0116
# INFO     |  AL update: snorm=4.6194e-07, csupn=4.6194e-07, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #10: cost=0.0106 criteria=[0 1 0], term_deltas=1.2e-04,1.8e-05,1.1e-04
# INFO     | Augmented Lagrangian: initial snorm=5.0005e-03, csupn=5.0005e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0106 lambd=0.0005
# INFO     |      - variance_cost(1): 0.01055 (avg 0.00264)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.73e-02 cost_prev=0.0108 cost_new=0.0093
# INFO     |  step #1: cost=0.0072 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00717 (avg 0.00179)
# INFO     |      - augmented_return_constraint(1): 0.00213 (avg 0.00213)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=7.06e-05 cost_prev=0.0093 cost_new=0.0093
# INFO     |  AL update: snorm=1.4673e-02, csupn=1.4673e-02, max_rho=4.0000e+01
# INFO     |  step #2: cost=0.0072 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00715 (avg 0.00179)
# INFO     |      - augmented_return_constraint(1): 0.01346 (avg 0.01346)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.88e-02 cost_prev=0.0206 cost_new=0.0131
# INFO     |  step #3: cost=0.0119 lambd=0.0001
# INFO     |      - variance_cost(1): 0.01187 (avg 0.00297)
# INFO     |      - augmented_return_constraint(1): 0.00124 (avg 0.00124)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.39e-05 cost_prev=0.0131 cost_new=0.0131
# INFO     |  AL update: snorm=1.9019e-03, csupn=1.9019e-03, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0119 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01188 (avg 0.00297)
# INFO     |      - augmented_return_constraint(1): 0.00223 (avg 0.00223)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=7.87e-03 cost_prev=0.0141 cost_new=0.0140
# INFO     |  AL update: snorm=2.4709e-04, csupn=2.4709e-04, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0126 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01263 (avg 0.00316)
# INFO     |      - augmented_return_constraint(1): 0.00147 (avg 0.00147)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.00e-03 cost_prev=0.0141 cost_new=0.0141
# INFO     |  AL update: snorm=3.1851e-05, csupn=3.1851e-05, max_rho=4.0000e+01
# INFO     |  step #6: cost=0.0127 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01273 (avg 0.00318)
# INFO     |      - augmented_return_constraint(1): 0.00138 (avg 0.00138)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.40e-04 cost_prev=0.0141 cost_new=0.0141
# INFO     |  AL update: snorm=4.1127e-06, csupn=4.1127e-06, max_rho=4.0000e+01
# INFO     |  step #7: cost=0.0127 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01275 (avg 0.00319)
# INFO     |      - augmented_return_constraint(1): 0.00137 (avg 0.00137)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.69e-05 cost_prev=0.0141 cost_new=0.0141
# INFO     |  AL update: snorm=5.2899e-07, csupn=5.2899e-07, max_rho=4.0000e+01
# INFO     |  step #8: cost=0.0127 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01275 (avg 0.00319)
# INFO     |      - augmented_return_constraint(1): 0.00137 (avg 0.00137)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #9: cost=0.0127 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01275 (avg 0.00319)
# INFO     |      - augmented_return_constraint(1): 0.00137 (avg 0.00137)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=False ATb_norm=8.32e-06 cost_prev=0.0141 cost_new=0.0141
# INFO     |  AL update: snorm=5.2899e-07, csupn=5.2899e-07, max_rho=1.6000e+02
# INFO     | Terminated @ iteration #10: cost=0.0127 criteria=[0 1 0], term_deltas=1.7e-05,5.0e-06,1.6e-05
# INFO     | Augmented Lagrangian: initial snorm=5.0005e-03, csupn=5.0005e-03, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #0: cost=0.0127 lambd=0.0005
# INFO     |      - variance_cost(1): 0.01275 (avg 0.00319)
# INFO     |      - augmented_return_constraint(1): 0.00025 (avg 0.00025)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.04e-02 cost_prev=0.0130 cost_new=0.0109
# INFO     |  step #1: cost=0.0082 lambd=0.0003
# INFO     |      - variance_cost(1): 0.00816 (avg 0.00204)
# INFO     |      - augmented_return_constraint(1): 0.00271 (avg 0.00271)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.42e-05 cost_prev=0.0109 cost_new=0.0109
# INFO     |  AL update: snorm=1.6535e-02, csupn=1.6535e-02, max_rho=4.0000e+01
# INFO     |  step #2: cost=0.0081 lambd=0.0001
# INFO     |      - variance_cost(1): 0.00813 (avg 0.00203)
# INFO     |      - augmented_return_constraint(1): 0.01709 (avg 0.01709)
# INFO     |      - augmented_budget_constraint(1): 0.00002 (avg 0.00002)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=9.62e-02 cost_prev=0.0252 cost_new=0.0157
# INFO     |  step #3: cost=0.0141 lambd=0.0001
# INFO     |      - variance_cost(1): 0.01413 (avg 0.00353)
# INFO     |      - augmented_return_constraint(1): 0.00158 (avg 0.00158)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.80e-05 cost_prev=0.0157 cost_new=0.0157
# INFO     |  AL update: snorm=2.1437e-03, csupn=2.1437e-03, max_rho=4.0000e+01
# INFO     |  step #4: cost=0.0141 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01413 (avg 0.00353)
# INFO     |      - augmented_return_constraint(1): 0.00284 (avg 0.00284)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.87e-03 cost_prev=0.0170 cost_new=0.0168
# INFO     |  AL update: snorm=2.7850e-04, csupn=2.7850e-04, max_rho=4.0000e+01
# INFO     |  step #5: cost=0.0151 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01509 (avg 0.00377)
# INFO     |      - augmented_return_constraint(1): 0.00187 (avg 0.00187)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.14e-03 cost_prev=0.0170 cost_new=0.0170
# INFO     |  AL update: snorm=3.5897e-05, csupn=3.5897e-05, max_rho=4.0000e+01
# INFO     |  step #6: cost=0.0152 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01522 (avg 0.00380)
# INFO     |      - augmented_return_constraint(1): 0.00176 (avg 0.00176)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.60e-04 cost_prev=0.0170 cost_new=0.0170
# INFO     |  AL update: snorm=4.6417e-06, csupn=4.6417e-06, max_rho=4.0000e+01
# INFO     |  step #7: cost=0.0152 lambd=0.0000
# INFO     |      - variance_cost(1): 0.01524 (avg 0.00381)
# INFO     |      - augmented_return_constraint(1): 0.00174 (avg 0.00174)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.69e-05 cost_prev=0.0170 cost_new=0.0170
# INFO     |  AL update: snorm=6.0350e-07, csupn=6.0350e-07, max_rho=4.0000e+01
# INFO     |  step #8: cost=0.0152 lambd=0.0000
# ...
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |  step #18: cost=0.0249 lambd=0.0080
# INFO     |      - variance_cost(1): 0.02491 (avg 0.00623)
# INFO     |      - augmented_return_constraint(1): 0.01204 (avg 0.01204)
# INFO     |      - augmented_budget_constraint(1): 0.00002 (avg 0.00002)
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=4.12e-03 cost_prev=0.0370 cost_new=0.0369
# INFO     |  AL update: snorm=1.4040e-03, csupn=1.4040e-03, max_rho=1.6000e+02
# INFO     |  step #19: cost=0.0266 lambd=0.0040
# INFO     |      - variance_cost(1): 0.02659 (avg 0.00665)
# INFO     |      - augmented_return_constraint(1): 0.01190 (avg 0.01190)
# INFO     |      - augmented_budget_constraint(1): 0.00002 (avg 0.00002)
# INFO     |      - augmented_no_short_selling(1): 0.00050 (avg 0.00012)
# INFO     |      accepted=True ATb_norm=3.47e-01 cost_prev=0.0390 cost_new=0.0385
# INFO     |  step #20: cost=0.0269 lambd=0.0020
# INFO     |      - variance_cost(1): 0.02694 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.01154 (avg 0.01154)
# INFO     |      - augmented_budget_constraint(1): 0.00002 (avg 0.00002)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.40e-05 cost_prev=0.0385 cost_new=0.0385
# INFO     |  AL update: snorm=9.8248e-04, csupn=9.8248e-04, max_rho=6.4000e+02
# INFO     |  step #21: cost=0.0270 lambd=0.0010
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #22: cost=0.0270 lambd=0.0020
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #23: cost=0.0270 lambd=0.0040
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #24: cost=0.0270 lambd=0.0080
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #25: cost=0.0270 lambd=0.0160
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #26: cost=0.0270 lambd=0.0320
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #27: cost=0.0270 lambd=0.0640
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #28: cost=0.0270 lambd=0.1280
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #29: cost=0.0270 lambd=0.2560
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #30: cost=0.0270 lambd=0.5120
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #31: cost=0.0270 lambd=1.0240
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #32: cost=0.0270 lambd=2.0480
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #33: cost=0.0270 lambd=4.0960
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #34: cost=0.0270 lambd=8.1920
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #35: cost=0.0270 lambd=16.3840
# INFO     |      - variance_cost(1): 0.02697 (avg 0.00674)
# INFO     |      - augmented_return_constraint(1): 0.00436 (avg 0.00436)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.35e-02 cost_prev=0.0313 cost_new=0.0313
# INFO     |  step #36: cost=0.0270 lambd=8.1920
# INFO     |      - variance_cost(1): 0.02699 (avg 0.00675)
# INFO     |      - augmented_return_constraint(1): 0.00434 (avg 0.00434)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.65e-03 cost_prev=0.0313 cost_new=0.0313
# INFO     |  AL update: snorm=9.5949e-04, csupn=9.5949e-04, max_rho=2.5600e+03
# INFO     |  step #37: cost=0.0270 lambd=4.0960
# INFO     |      - variance_cost(1): 0.02700 (avg 0.00675)
# INFO     |      - augmented_return_constraint(1): 0.00327 (avg 0.00327)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.34e-02 cost_prev=0.0303 cost_new=0.0302
# INFO     |  step #38: cost=0.0271 lambd=2.0480
# INFO     |      - variance_cost(1): 0.02707 (avg 0.00677)
# INFO     |      - augmented_return_constraint(1): 0.00311 (avg 0.00311)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.27e-02 cost_prev=0.0302 cost_new=0.0301
# INFO     |  step #39: cost=0.0272 lambd=1.0240
# INFO     |      - variance_cost(1): 0.02721 (avg 0.00680)
# INFO     |      - augmented_return_constraint(1): 0.00285 (avg 0.00285)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.14e-02 cost_prev=0.0301 cost_new=0.0299
# INFO     |  step #40: cost=0.0274 lambd=0.5120
# INFO     |      - variance_cost(1): 0.02743 (avg 0.00686)
# INFO     |      - augmented_return_constraint(1): 0.00244 (avg 0.00244)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=9.25e-03 cost_prev=0.0299 cost_new=0.0297
# INFO     |  AL update: snorm=4.3818e-04, csupn=4.3818e-04, max_rho=2.5600e+03
# INFO     |  step #41: cost=0.0277 lambd=0.2560
# INFO     |      - variance_cost(1): 0.02775 (avg 0.00694)
# INFO     |      - augmented_return_constraint(1): 0.00303 (avg 0.00303)
# INFO     |      - augmented_budget_constraint(1): 0.00001 (avg 0.00001)
# INFO     |      - augmented_no_short_selling(1): 0.00001 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.13e-02 cost_prev=0.0308 cost_new=0.0304
# INFO     |  step #42: cost=0.0284 lambd=0.1280
# INFO     |      - variance_cost(1): 0.02837 (avg 0.00709)
# INFO     |      - augmented_return_constraint(1): 0.00203 (avg 0.00203)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=5.84e-03 cost_prev=0.0304 cost_new=0.0303
# INFO     |  AL update: snorm=2.3507e-04, csupn=6.3777e-06, max_rho=1.0240e+04
# INFO     |  step #43: cost=0.0288 lambd=0.0640
# INFO     |      - variance_cost(1): 0.02883 (avg 0.00721)
# INFO     |      - augmented_return_constraint(1): 0.00103 (avg 0.00103)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.21e-01 cost_prev=0.0299 cost_new=0.0299
# INFO     |  step #44: cost=0.0288 lambd=0.0320
# INFO     |      - variance_cost(1): 0.02877 (avg 0.00719)
# INFO     |      - augmented_return_constraint(1): 0.00108 (avg 0.00108)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.73e-04 cost_prev=0.0299 cost_new=0.0299
# INFO     |  AL update: snorm=1.9302e-04, csupn=1.3113e-06, max_rho=1.0240e+04
# INFO     |  step #45: cost=0.0288 lambd=0.0160
# INFO     |      - variance_cost(1): 0.02876 (avg 0.00719)
# INFO     |      - augmented_return_constraint(1): 0.00080 (avg 0.00080)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.33e-03 cost_prev=0.0296 cost_new=0.0295
# INFO     |  AL update: snorm=4.3318e-05, csupn=2.3842e-07, max_rho=1.0240e+04
# INFO     |  step #46: cost=0.0285 lambd=0.0080
# INFO     |      - variance_cost(1): 0.02851 (avg 0.00713)
# INFO     |      - augmented_return_constraint(1): 0.00096 (avg 0.00096)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=3.42e-03 cost_prev=0.0295 cost_new=0.0295
# INFO     |  AL update: snorm=1.0356e-06, csupn=1.0356e-06, max_rho=1.0240e+04
# INFO     |  step #47: cost=0.0284 lambd=0.0040
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=2.04e-03 cost_prev=0.0287 cost_new=0.0287
# INFO     |  AL update: snorm=4.5449e-07, csupn=4.5449e-07, max_rho=4.0960e+04
# INFO     |  step #48: cost=0.0284 lambd=0.0020
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #49: cost=0.0284 lambd=0.0040
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #50: cost=0.0284 lambd=0.0080
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #51: cost=0.0284 lambd=0.0160
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #52: cost=0.0284 lambd=0.0320
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #53: cost=0.0284 lambd=0.0640
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=8.02e-03 cost_prev=0.0287 cost_new=0.0287
# INFO     |  AL update: snorm=4.4703e-08, csupn=4.4703e-08, max_rho=4.0960e+04
# INFO     |  step #54: cost=0.0284 lambd=0.0320
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #55: cost=0.0284 lambd=0.0640
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |  step #56: cost=0.0284 lambd=0.1280
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.71e-03 cost_prev=0.0287 cost_new=0.0287
# INFO     |  AL update: snorm=2.2352e-08, csupn=0.0000e+00, max_rho=4.0960e+04
# INFO     |  step #57: cost=0.0284 lambd=0.0640
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.65e-03 cost_prev=0.0287 cost_new=0.0287
# INFO     |  AL update: snorm=7.4506e-09, csupn=0.0000e+00, max_rho=4.0960e+04
# INFO     |  step #58: cost=0.0284 lambd=0.0320
# INFO     |      - variance_cost(1): 0.02844 (avg 0.00711)
# INFO     |      - augmented_return_constraint(1): 0.00026 (avg 0.00026)
# INFO     |      - augmented_budget_constraint(1): 0.00000 (avg 0.00000)
# INFO     |      - augmented_no_short_selling(1): 0.00000 (avg 0.00000)
# INFO     |      accepted=True ATb_norm=1.65e-03 cost_prev=0.0287 cost_new=0.0287
# INFO     |  AL update: snorm=7.4506e-09, csupn=7.4506e-09, max_rho=4.0960e+04
# INFO     | Terminated @ iteration #59: cost=0.0284 criteria=[0 0 1], term_deltas=5.2e-07,8.3e-04,9.3e-07
# Computed 15 points on the efficient frontier

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from IPython.display import HTML

colors = ["#2196F3", "#4CAF50", "#FF9800", "#9C27B0"]

# Convert JAX arrays to Python floats for Plotly.
std_devs_list = [float(s) * 100 for s in std_devs]
returns_list = [float(r) * 100 for r in returns_achieved]

fig = make_subplots(
    rows=1,
    cols=2,
    subplot_titles=("Efficient Frontier", "Asset Allocation"),
    column_widths=[0.4, 0.6],
)

# Left plot: Efficient frontier.
fig.add_trace(
    go.Scatter(
        x=std_devs_list,
        y=returns_list,
        mode="lines+markers",
        marker=dict(size=6, color=returns_list, colorscale="Viridis", showscale=False),
        line=dict(color="steelblue", width=2),
        hovertemplate="Std Dev: %{x:.1f}%<br>Return: %{y:.1f}%<extra></extra>",
        showlegend=False,
    ),
    row=1,
    col=1,
)

# Right plot: Asset allocation (use target_returns for x-axis to avoid stacking.
# bars at duplicate achieved returns when return constraint isn't binding)
for i, (name, color) in enumerate(zip(asset_names, colors)):
    fig.add_trace(
        go.Bar(
            x=[float(t) * 100 for t in target_returns],
            y=[float(w) * 100 for w in all_weights[:, i]],
            name=name,
            marker_color=color,
            hovertemplate=f"{name}: %{{y:.1f}}%<extra></extra>",
        ),
        row=1,
        col=2,
    )

fig.update_xaxes(title_text="Std Deviation (%)", row=1, col=1)
fig.update_yaxes(title_text="Return (%)", row=1, col=1)
fig.update_xaxes(title_text="Target Return (%)", row=1, col=2)
fig.update_yaxes(title_text="Allocation (%)", range=[0, 105], row=1, col=2)

fig.update_layout(
    barmode="stack",
    height=400,
    margin=dict(t=40, b=40, l=60, r=40),
    legend=dict(orientation="h", yanchor="bottom", y=-0.25, xanchor="center", x=0.75),
)
HTML(fig.to_html(full_html=False, include_plotlyjs="cdn"))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="1c9d7078-f5aa-49d3-bc85-e00d19d5dd94" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1c9d7078-f5aa-49d3-bc85-e00d19d5dd94")) {                    Plotly.newPlot(                        "1c9d7078-f5aa-49d3-bc85-e00d19d5dd94",                        [{"hovertemplate":"Std Dev: %{x:.1f}%\u003cbr\u003eReturn: %{y:.1f}%\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"steelblue","width":2},"marker":{"color":[5.563114583492279,5.563113838434219,5.563113838434219,5.999572575092316,6.499997526407242,6.999851763248444,7.499837875366211,7.999967038631439,8.499693125486374,8.999952673912048,9.499946981668472,9.999997913837433,10.500000417232513,11.000000685453415,11.499998718500137],"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"showscale":false,"size":6},"mode":"lines+markers","showlegend":false,"x":[5.940801277756691,5.940800905227661,5.940800905227661,6.035405024886131,6.365031749010086,6.89711719751358,7.589594274759293,8.403059840202332,9.30495336651802,10.27352288365364,11.290384829044342,12.344112247228622,13.457289338111877,14.950746297836304,16.863413155078888],"y":[5.563114583492279,5.563113838434219,5.563113838434219,5.999572575092316,6.499997526407242,6.999851763248444,7.499837875366211,7.999967038631439,8.499693125486374,8.999952673912048,9.499946981668472,9.999997913837433,10.500000417232513,11.000000685453415,11.499998718500137],"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"Tech: %{y:.1f}%\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#2196F3"},"name":"Tech","x":[4.4999998062849045,4.999999701976776,5.499999970197678,5.999999493360519,6.499999761581421,7.000000029802322,7.499999552965164,7.999999821186066,8.499999344348907,8.999999612569809,9.49999988079071,9.999999403953552,10.499999672174454,10.999999940395355,11.499999463558197],"y":[9.242627769708633,9.242626279592514,9.242627024650574,12.311934679746628,15.831075608730316,19.346198439598083,22.862346470355988,26.379308104515076,29.893535375595093,33.41151177883148,36.92761957645416,40.444135665893555,47.05163538455963,59.31674838066101,74.99990463256836],"type":"bar","xaxis":"x2","yaxis":"y2"},{"hovertemplate":"Healthcare: %{y:.1f}%\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#4CAF50"},"name":"Healthcare","x":[4.4999998062849045,4.999999701976776,5.499999970197678,5.999999493360519,6.499999761581421,7.000000029802322,7.499999552965164,7.999999821186066,8.499999344348907,8.999999612569809,9.49999988079071,9.999999403953552,10.499999672174454,10.999999940395355,11.499999463558197],"y":[7.524219900369644,7.524218410253525,7.5242191553115845,9.2681385576725,11.267653107643127,13.264879584312439,15.262468159198761,17.260967195034027,19.257676601409912,21.25653773546219,23.25432300567627,25.252345204353333,22.051602602005005,9.316758811473846,-1.2357448397892767e-9],"type":"bar","xaxis":"x2","yaxis":"y2"},{"hovertemplate":"Energy: %{y:.1f}%\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#FF9800"},"name":"Energy","x":[4.4999998062849045,4.999999701976776,5.499999970197678,5.999999493360519,6.499999761581421,7.000000029802322,7.499999552965164,7.999999821186066,8.499999344348907,8.999999612569809,9.49999988079071,9.999999403953552,10.499999672174454,10.999999940395355,11.499999463558197],"y":[8.712256699800491,8.712255209684372,8.712255954742432,10.731539130210876,13.046763837337494,15.3593420982 ...

# %% [markdown]
# ## How it works: Augmented Lagrangian
#
# When constraints are present, jaxls uses an Augmented Lagrangian method.
#
# ### The augmented Lagrangian
#
# The method adds both a linear term (Lagrange multiplier $\lambda$) and a quadratic penalty to the objective:
#
# $$\mathcal{L}(x, \lambda, \rho) = f(x) + \lambda \cdot h(x) + \frac{\rho}{2} h(x)^2$$
#
# The multiplier $\lambda$ handles steady-state enforcement while the penalty $\rho$ accelerates convergence.
#
# ### Multiplier updates
#
# As the solver runs, it updates the multipliers based on constraint violations:
#
# $$\lambda_{\text{new}} = \lambda + \rho \cdot h(x)$$
#
# For inequality constraints $g(x) \leq 0$, this is projected to stay non-negative:
# $\lambda_{\text{new}} = \max(0, \lambda + \rho \cdot g(x))$.
#
# Updates occur when the cost stabilizes, indicating the current subproblem is solved.
# The penalty $\rho$ increases if constraints aren't improving fast enough.

# %% [markdown]
# ## Advanced: tuning the solver
#
# For difficult problems, you can tune the Augmented Lagrangian solver via {class}`~jaxls.AugmentedLagrangianConfig`.
# The parameters map to the concepts above. Max iterations can be controlled via {class}`~jaxls.TerminationConfig`:

# %%
# Custom configuration example.
al_config = jaxls.AugmentedLagrangianConfig(
    penalty_factor=10.0,  # Multiply rho by this when constraints stagnate.
    penalty_max=1e7,  # Cap on rho to prevent ill-conditioning.
    tolerance_absolute=1e-6,  # Constraint violation tolerance for convergence.
)

# Use with solve(). Max iterations is controlled via TerminationConfig.
solution = problem.solve(
    verbose=False,
    linear_solver="dense_cholesky",
    augmented_lagrangian=al_config,
    termination=jaxls.TerminationConfig(max_iterations=150),
)

print("Solution with custom config:")
for name, w in zip(asset_names, solution[weights_var]):
    print(f"  {name}: {float(w):.1%}")
# Out:
# Solution with custom config:
#   Tech: 26.4%
#   Healthcare: 17.3%
#   Energy: 20.0%
#   Bonds: 36.4%

# %% [markdown]
# ## Alternative: manifold reformulation
#
# Some constraints can be reformulated as manifold optimization via custom `retract_fn`.
# For example, the budget constraint (weights sum to 1) and no short-selling constraint
# (weights non-negative) together define the probability simplex, which is a manifold that can
# be optimized directly without explicit constraints.
#
# This approach can be more numerically stable when the constraints define a smooth manifold
# with a simple retraction. See {doc}`../../examples/portfolio/manifold_allocation` for an example.
#
# ## Summary
#
# Key points for constrained optimization in jaxls:
#
# - Use `kind="constraint_eq_zero"` for equality constraints $h(x) = 0$
# - Use `kind="constraint_leq_zero"` for upper bounds $g(x) \leq 0$
# - Use `kind="constraint_geq_zero"` for lower bounds $g(x) \geq 0$
# - Constraints are handled automatically via Augmented Lagrangian
# - Tune with {class}`~jaxls.AugmentedLagrangianConfig` if needed
#
# For more constraint examples, see:
# - {doc}`../../examples/portfolio/mean_variance`: Portfolio optimization with return targets
# - {doc}`../../examples/robotics/inverse_kinematics`: Position/orientation constraints with joint limits
# - {doc}`../../examples/robotics/obstacle_avoidance`: Collision avoidance inequalities
# - {doc}`../../examples/robotics/cart_pole_collocation`: Dynamics as equality constraints
