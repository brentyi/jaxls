# %% [markdown]
# # Truss Analysis
#
# A 2D truss structure analysis: finding the equilibrium displacements of a pin-jointed frame under load.
#
# Features used:
# - {class}`~jaxls.Var` subclassing for node displacement variables
# - {func}`@jaxls.Cost.factory <jaxls.Cost.factory>` for bar element strain energy
# - Equality constraints for fixed supports
# - Batched cost construction for all members
#
# This is a classic introductory finite element analysis (FEA) problem using 1D bar elements.

# %%
import sys
from loguru import logger

logger.remove()
logger.add(sys.stdout, format="<level>{level: <8}</level> | {message}");

# %%
import jax
import jax.numpy as jnp
import jaxls

# %% [markdown]
# ## Truss element theory
#
# A truss is a structure of bar elements connected at pin joints (nodes). Each bar:
# - Carries only axial force (tension or compression)
# - Has stiffness $k = \frac{EA}{L}$ where $E$ is Young's modulus, $A$ is cross-sectional area, $L$ is length
#
# The strain energy in a bar element is:
# $$U = \frac{1}{2} k (\Delta L)^2 = \frac{1}{2} \frac{EA}{L} (L' - L)^2$$
#
# where $L'$ is the deformed length.

# %%
class NodeVar(jaxls.Var[jax.Array], default_factory=lambda: jnp.zeros(2)):
    """2D node displacement variable [dx, dy] in meters."""

# %% [markdown]
# ## Cost functions
#
# 1. Bar strain energy: Penalizes elongation/compression of each member
# 2. Support constraints: Fix displacements at support nodes
# 3. Load application: Prescribe displacement at load point (equilibrium is automatic)

# %%
@jaxls.Cost.factory
def bar_strain_energy(
    vals: jaxls.VarValues,
    node_i: NodeVar,
    node_j: NodeVar,
    pos_i: jax.Array,
    pos_j: jax.Array,
    EA: float,
) -> jax.Array:
    """Strain energy in a bar element: (1/2) * EA/L * (delta_L)^2.

    Args:
        node_i, node_j: Displacement variables at each end.
        pos_i, pos_j: Initial (undeformed) positions.
        EA: Axial stiffness (Young's modulus × area).
    """
    # Initial geometry.
    L0_vec = pos_j - pos_i
    L0 = jnp.sqrt(jnp.sum(L0_vec**2))

    # Deformed geometry.
    disp_i = vals[node_i]
    disp_j = vals[node_j]
    L_vec = L0_vec + (disp_j - disp_i)
    L = jnp.sqrt(jnp.sum(L_vec**2))

    # Return 2D residual instead of scalar: ||r||^2 = (EA/L0) * (L - L0)^2.
    # Using a 2D residual gives a rank-2 contribution to J^T J (the Gauss-Newton.
    # Hessian approximation), rather than rank-1 from a scalar residual.
    return jnp.sqrt(EA / L0) * (1 - L0 / L) * L_vec


@jaxls.Cost.factory(kind="constraint_eq_zero")
def pin_support(
    vals: jaxls.VarValues,
    node: NodeVar,
) -> jax.Array:
    """Pin support: both displacement components are zero."""
    return vals[node]


@jaxls.Cost.factory(kind="constraint_eq_zero")
def prescribed_displacement(
    vals: jaxls.VarValues,
    node: NodeVar,
    target_displacement: jax.Array,
) -> jax.Array:
    """Prescribe displacement at a node."""
    return vals[node] - target_displacement

# %% [markdown]
# ## Truss geometry
#
# We model a Warren truss, a common bridge structure with diagonal members:
#
# ```
#    5-----6-----7-----8
#   /\    /\    /\    /\
#  /  \  /  \  /  \  /  \
# /    \/    \/    \/    \
# 0-----1-----2-----3-----4
# ```
#
# - Nodes 0-4: Bottom chord
# - Nodes 5-8: Top chord
# - Nodes 0 and 4 are pinned (fixed in x and y)
# - Load applied at center bottom node (node 2)

# %%
# Geometry: Warren truss bridge.
num_panels = 4  # Number of triangular panels
panel_width = 3.0  # [m] width of each panel
height = 2.0  # [m] truss height
span = num_panels * panel_width  # Total span

# Build node positions.
bottom_nodes = [[i * panel_width, 0.0] for i in range(num_panels + 1)]
top_nodes = [[(i + 0.5) * panel_width, height] for i in range(num_panels)]
node_positions = jnp.array(bottom_nodes + top_nodes)
num_nodes = len(node_positions)

# Node indices.
bottom_ids = list(range(num_panels + 1))  # 0, 1, 2, 3, 4
top_ids = list(range(num_panels + 1, num_nodes))  # 5, 6, 7, 8

# Build member connectivity.
member_list = []
# Bottom chord.
for i in range(num_panels):
    member_list.append([bottom_ids[i], bottom_ids[i + 1]])
# Top chord.
for i in range(num_panels - 1):
    member_list.append([top_ids[i], top_ids[i + 1]])
# Diagonals (left and right of each top node)
for i in range(num_panels):
    member_list.append([bottom_ids[i], top_ids[i]])  # Left diagonal
    member_list.append([top_ids[i], bottom_ids[i + 1]])  # Right diagonal

members = jnp.array(member_list)
num_members = len(members)

# Material properties.
EA = 50000.0  # [N] axial stiffness

# Load node.
load_node_id = 2  # Center bottom node

# Prescribed displacement (downward)
load_displacement = jnp.array([0.0, -0.02])  # 20 mm downward

print("Warren Truss Bridge:")
print(f"  Span: {span} m, Height: {height} m")
print(f"  Nodes: {num_nodes}, Members: {num_members}")
print(f"  Member stiffness EA = {EA:.0f} N")
print(
    f"  Prescribed displacement at node {load_node_id}: {float(load_displacement[1]) * 1000:.1f} mm (vertical)"
)
# Out:
# Warren Truss Bridge:
#   Span: 12.0 m, Height: 2.0 m
#   Nodes: 9, Members: 15
#   Member stiffness EA = 50000 N
#   Prescribed displacement at node 2: -20.0 mm (vertical)

# %% [markdown]
# ## Problem construction

# %%
# Create node displacement variables.
node_vars = NodeVar(id=jnp.arange(num_nodes))

# Support nodes (both pinned).
left_pin = 0
right_pin = num_panels

# Build costs.
costs: list[jaxls.Cost] = [
    # Strain energy in all members (batched).
    bar_strain_energy(
        NodeVar(id=members[:, 0]),
        NodeVar(id=members[:, 1]),
        node_positions[members[:, 0]],
        node_positions[members[:, 1]],
        EA,
    ),
    # Boundary conditions.
    pin_support(NodeVar(id=left_pin)),
    pin_support(NodeVar(id=right_pin)),
    # Applied load via prescribed displacement.
    prescribed_displacement(NodeVar(id=load_node_id), load_displacement),
]

print(f"Created {len(costs)} cost objects")
print(f"Load applied at node {load_node_id}")
# Out:
# Created 4 cost objects
# Load applied at node 2

# %% [markdown]
# ## Solving

# %%
# Initial values: zero displacement.
initial_displacements = jnp.zeros((num_nodes, 2))
initial_vals = jaxls.VarValues.make([node_vars.with_value(initial_displacements)])

# Solve.
problem = jaxls.LeastSquaresProblem(costs, [node_vars]).analyze()
solution = problem.solve(initial_vals)
# Out:
# INFO     | Building optimization problem with 18 terms and 9 variables: 15 costs, 3 eq_zero, 0 leq_zero, 0 geq_zero
# INFO     | Vectorizing group with 15 costs, 2 variables each: bar_strain_energy
# INFO     | Vectorizing constraint group with 2 constraints (constraint_eq_zero), 1 variables each: augmented_pin_support
# INFO     | Vectorizing constraint group with 1 constraints (constraint_eq_zero), 1 variables each: augmented_prescribed_displacement
# INFO     | Augmented Lagrangian: initial snorm=2.0000e-02, csupn=2.0000e-02, max_rho=1.0000e+01, constraint_dim=6
# INFO     |  step #1: cost=0.0040 lambd=0.0005 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.00000 (avg 0.00000)
# INFO     |      - augmented_pin_support(2): 0.00000 (avg 0.00000)
# INFO     |      - augmented_prescribed_displacement(1): 0.00400 (avg 0.00200)
# INFO     |  AL update: snorm=1.3288e-02, csupn=1.3288e-02, max_rho=2.0000e+01
# INFO     |  step #2: cost=0.0119 lambd=0.0003 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.00001 (avg 0.00000)
# INFO     |      - augmented_pin_support(2): 0.00397 (avg 0.00099)
# INFO     |      - augmented_prescribed_displacement(1): 0.00795 (avg 0.00397)
# INFO     |  AL update: snorm=1.3232e-02, csupn=1.3232e-02, max_rho=4.0000e+01
# INFO     |  step #3: cost=0.0321 lambd=0.0001 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.00008 (avg 0.00000)
# INFO     |      - augmented_pin_support(2): 0.01058 (avg 0.00265)
# INFO     |      - augmented_prescribed_displacement(1): 0.02147 (avg 0.01074)
# INFO     |  AL update: snorm=1.3120e-02, csupn=1.3120e-02, max_rho=8.0000e+01
# INFO     |  step #4: cost=0.0724 lambd=0.0001 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.00044 (avg 0.00001)
# INFO     |      - augmented_pin_support(2): 0.02331 (avg 0.00583)
# INFO     |      - augmented_prescribed_displacement(1): 0.04861 (avg 0.02430)
# INFO     |  AL update: snorm=1.2593e-02, csupn=1.2593e-02, max_rho=1.6000e+02
# INFO     |  step #5: cost=0.1486 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.00195 (avg 0.00007)
# INFO     |      - augmented_pin_support(2): 0.04940 (avg 0.01235)
# INFO     |      - augmented_prescribed_displacement(1): 0.09726 (avg 0.04863)
# INFO     |  AL update: snorm=1.1989e-02, csupn=1.1989e-02, max_rho=3.2000e+02
# INFO     |  step #6: cost=0.2847 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.00771 (avg 0.00026)
# INFO     |      - augmented_pin_support(2): 0.09247 (avg 0.02312)
# INFO     |      - augmented_prescribed_displacement(1): 0.18453 (avg 0.09227)
# INFO     |  AL update: snorm=1.0797e-02, csupn=1.0797e-02, max_rho=6.4000e+02
# INFO     |  step #7: cost=0.5023 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.02744 (avg 0.00091)
# INFO     |      - augmented_pin_support(2): 0.15924 (avg 0.03981)
# INFO     |      - augmented_prescribed_displacement(1): 0.31566 (avg 0.15783)
# INFO     |  AL update: snorm=8.8794e-03, csupn=8.8794e-03, max_rho=1.2800e+03
# INFO     |  step #8: cost=0.7879 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.08478 (avg 0.00283)
# INFO     |      - augmented_pin_support(2): 0.23986 (avg 0.05996)
# INFO     |      - augmented_prescribed_displacement(1): 0.46328 (avg 0.23164)
# INFO     |  AL update: snorm=6.2853e-03, csupn=6.2853e-03, max_rho=2.5600e+03
# INFO     |  step #9: cost=1.0574 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.21340 (avg 0.00711)
# INFO     |      - augmented_pin_support(2): 0.30576 (avg 0.07644)
# INFO     |      - augmented_prescribed_displacement(1): 0.53828 (avg 0.26914)
# INFO     |  AL update: snorm=3.5962e-03, csupn=3.5962e-03, max_rho=5.1200e+03
# INFO     |  step #10: cost=1.2179 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.41451 (avg 0.01382)
# INFO     |      - augmented_pin_support(2): 0.34112 (avg 0.08528)
# INFO     |      - augmented_prescribed_displacement(1): 0.46227 (avg 0.23114)
# INFO     |  AL update: snorm=1.6257e-03, csupn=1.6257e-03, max_rho=1.0240e+04
# INFO     |  step #11: cost=1.4700 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.62819 (avg 0.02094)
# INFO     |      - augmented_pin_support(2): 0.41249 (avg 0.10312)
# INFO     |      - augmented_prescribed_displacement(1): 0.42933 (avg 0.21466)
# INFO     |  AL update: snorm=1.0104e-03, csupn=1.0104e-03, max_rho=2.0480e+04
# INFO     |  step #12: cost=1.3694 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.76184 (avg 0.02539)
# INFO     |      - augmented_pin_support(2): 0.32192 (avg 0.08048)
# INFO     |      - augmented_prescribed_displacement(1): 0.28563 (avg 0.14281)
# INFO     |  AL update: snorm=3.9067e-04, csupn=3.9067e-04, max_rho=2.0480e+04
# INFO     |  step #13: cost=1.4557 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.90285 (avg 0.03009)
# INFO     |      - augmented_pin_support(2): 0.29147 (avg 0.07287)
# INFO     |      - augmented_prescribed_displacement(1): 0.26138 (avg 0.13069)
# INFO     |  AL update: snorm=1.7479e-04, csupn=1.7479e-04, max_rho=2.0480e+04
# INFO     |  step #14: cost=1.4994 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.96724 (avg 0.03224)
# INFO     |      - augmented_pin_support(2): 0.27498 (avg 0.06874)
# INFO     |      - augmented_prescribed_displacement(1): 0.25715 (avg 0.12857)
# INFO     |  AL update: snorm=6.3842e-05, csupn=6.3842e-05, max_rho=2.0480e+04
# INFO     |  step #15: cost=1.5185 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 0.99552 (avg 0.03318)
# INFO     |      - augmented_pin_support(2): 0.27070 (avg 0.06767)
# INFO     |      - augmented_prescribed_displacement(1): 0.25234 (avg 0.12617)
# INFO     |  AL update: snorm=2.9694e-05, csupn=2.9694e-05, max_rho=2.0480e+04
# INFO     |  step #16: cost=1.5268 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.00711 (avg 0.03357)
# INFO     |      - augmented_pin_support(2): 0.26776 (avg 0.06694)
# INFO     |      - augmented_prescribed_displacement(1): 0.25188 (avg 0.12594)
# INFO     |  AL update: snorm=1.1036e-05, csupn=1.1036e-05, max_rho=4.0960e+04
# INFO     |  step #17: cost=1.5302 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01206 (avg 0.03374)
# INFO     |      - augmented_pin_support(2): 0.26699 (avg 0.06675)
# INFO     |      - augmented_prescribed_displacement(1): 0.25111 (avg 0.12555)
# INFO     |  AL update: snorm=5.0161e-06, csupn=5.0161e-06, max_rho=8.1920e+04
# INFO     |  step #18: cost=1.5315 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #19: cost=1.5315 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #20: cost=1.5315 lambd=0.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #21: cost=1.5315 lambd=0.0001 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #22: cost=1.5315 lambd=0.0002 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #23: cost=1.5315 lambd=0.0003 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #24: cost=1.5315 lambd=0.0006 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #25: cost=1.5315 lambd=0.0013 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #26: cost=1.5315 lambd=0.0026 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #27: cost=1.5315 lambd=0.0051 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #28: cost=1.5315 lambd=0.0102 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #29: cost=1.5315 lambd=0.0205 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #30: cost=1.5315 lambd=0.0410 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #31: cost=1.5315 lambd=0.0819 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #32: cost=1.5315 lambd=0.1638 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #33: cost=1.5315 lambd=0.3277 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #34: cost=1.5315 lambd=0.6554 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #35: cost=1.5315 lambd=1.3107 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #36: cost=1.5315 lambd=2.6214 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #37: cost=1.5315 lambd=5.2429 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #38: cost=1.5315 lambd=10.4858 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #39: cost=1.5315 lambd=20.9715 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #40: cost=1.5315 lambd=41.9430 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #41: cost=1.5315 lambd=83.8861 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #42: cost=1.5315 lambd=167.7722 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #43: cost=1.5315 lambd=335.5443 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #44: cost=1.5315 lambd=671.0886 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  step #45: cost=1.5315 lambd=1342.1772 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01400 (avg 0.03380)
# INFO     |      - augmented_pin_support(2): 0.26654 (avg 0.06664)
# INFO     |      - augmented_prescribed_displacement(1): 0.25101 (avg 0.12550)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=8.1920e+04
# INFO     |  step #46: cost=1.5008 lambd=671.0886 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #47: cost=1.5008 lambd=1342.1772 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #48: cost=1.5008 lambd=2684.3545 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #49: cost=1.5008 lambd=5368.7090 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #50: cost=1.5008 lambd=10737.4180 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #51: cost=1.5008 lambd=21474.8359 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #52: cost=1.5008 lambd=42949.6719 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #53: cost=1.5008 lambd=85899.3438 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #54: cost=1.5008 lambd=171798.6875 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #55: cost=1.5008 lambd=343597.3750 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #56: cost=1.5008 lambd=687194.7500 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  step #57: cost=1.5008 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.23512 (avg 0.05878)
# INFO     |      - augmented_prescribed_displacement(1): 0.25098 (avg 0.12549)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=1.6384e+05
# INFO     |  step #58: cost=1.2581 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.11777 (avg 0.02944)
# INFO     |      - augmented_prescribed_displacement(1): 0.12561 (avg 0.06281)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=3.2768e+05
# INFO     |  step #59: cost=1.1367 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.05909 (avg 0.01477)
# INFO     |      - augmented_prescribed_displacement(1): 0.06293 (avg 0.03146)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=6.5536e+05
# INFO     |  step #60: cost=1.0761 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.02976 (avg 0.00744)
# INFO     |      - augmented_prescribed_displacement(1): 0.03158 (avg 0.01579)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=1.3107e+06
# INFO     |  step #61: cost=1.0457 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.01509 (avg 0.00377)
# INFO     |      - augmented_prescribed_displacement(1): 0.01591 (avg 0.00796)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=2.6214e+06
# INFO     |  step #62: cost=1.0305 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.00776 (avg 0.00194)
# INFO     |      - augmented_prescribed_displacement(1): 0.00808 (avg 0.00404)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=5.2429e+06
# INFO     |  step #63: cost=1.0230 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.00410 (avg 0.00102)
# INFO     |      - augmented_prescribed_displacement(1): 0.00416 (avg 0.00208)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=1.0000e+07
# INFO     |  step #64: cost=1.0192 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.00228 (avg 0.00057)
# INFO     |      - augmented_prescribed_displacement(1): 0.00221 (avg 0.00110)
# INFO     |  AL update: snorm=2.3749e-06, csupn=2.3749e-06, max_rho=1.0000e+07
# INFO     |  step #65: cost=1.0173 lambd=1000000.0000 inexact_tol=1.0e-02
# INFO     |      - bar_strain_energy(15): 1.01471 (avg 0.03382)
# INFO     |      - augmented_pin_support(2): 0.00139 (avg 0.00035)
# INFO     |      - augmented_prescribed_displacement(1): 0.00123 (avg 0.00062)
# INFO     |  AL update: snorm=6.5565e-07, csupn=6.5565e-07, max_rho=1.0000e+07
# INFO     | Terminated @ iteration #65: cost=1.0175 criteria=[0 0 1 0], term_deltas=1.3e-04,1.0e+01,2.2e-07

# %% [markdown]
# ## Results and visualization

# %%
# Extract displacements.
displacements = solution[node_vars]
deformed_positions = node_positions + displacements


def compute_member_force(i: int, j: int, disp: jax.Array) -> jax.Array:
    """Compute axial force in member (positive = tension).

    Args:
        i: Start node index
        j: End node index
        disp: Node displacements array (num_nodes, 2)

    Returns:
        Axial force in the member (scalar)
    """
    L0_vec = node_positions[j] - node_positions[i]
    L0 = jnp.sqrt(jnp.sum(L0_vec**2))
    L_vec = L0_vec + (disp[j] - disp[i])
    L = jnp.sqrt(jnp.sum(L_vec**2))
    strain = (L - L0) / L0
    return EA * strain  # Force = EA * strain


member_forces = jax.vmap(lambda m: compute_member_force(m[0], m[1], displacements))(
    members
)

# Print results.
print("Node Displacements:")
print(f"{'Node':>4} {'dx [mm]':>10} {'dy [mm]':>10}")
print("-" * 26)
for i in range(num_nodes):
    dx, dy = displacements[i] * 1000  # Convert to mm
    print(f"{i:>4} {float(dx):>10.3f} {float(dy):>10.3f}")

print("\nMember Forces:")
print(f"{'Member':>6} {'Force [kN]':>12} {'Type':>10}")
print("-" * 30)
for idx, m in enumerate(members):
    f = member_forces[idx]
    f_kN = float(f) / 1000
    typ = "Tension" if f > 0 else "Compression"
    print(f"{int(m[0])}-{int(m[1]):>2} {f_kN:>12.2f} {typ:>10}")
# Out:
# Node Displacements:
# Node    dx [mm]    dy [mm]
# --------------------------
#    0     -0.000     -0.000
#    1     -1.152    -11.738
#    2      0.000    -19.999
#    3      1.152    -11.738
#    4      0.000     -0.000
#    5      4.598     -5.452
#    6      2.287    -16.314
#    7     -2.287    -16.314
#    8     -4.598     -5.452
#
# Member Forces:
# Member   Force [kN]       Type
# ------------------------------
# 0- 1        -0.02 Compression
# 1- 2         0.02    Tension
# 2- 3         0.02    Tension
# 3- 4        -0.02 Compression
# 5- 6        -0.04 Compression
# 6- 7        -0.08 Compression
# 7- 8        -0.04 Compression
# 0- 5        -0.03 Compression
# 5- 1         0.03    Tension
# 1- 6        -0.03 Compression
# 6- 2         0.03    Tension
# 2- 7         0.03    Tension
# 7- 3        -0.03 Compression
# 3- 8         0.03    Tension
# 8- 4        -0.03 Compression

# %%
import plotly.graph_objects as go
from IPython.display import HTML

# Visualization.
scale = 20  # Displacement magnification for visibility
scaled_deformed = node_positions + scale * displacements

fig = go.Figure()

# Original structure (gray)
for m in members:
    i, j = int(m[0]), int(m[1])
    fig.add_trace(
        go.Scatter(
            x=[float(node_positions[i, 0]), float(node_positions[j, 0])],
            y=[float(node_positions[i, 1]), float(node_positions[j, 1])],
            mode="lines",
            line=dict(color="lightgray", width=6),
            showlegend=False,
        )
    )

# Deformed structure (colored by force)
max_force = float(jnp.max(jnp.abs(member_forces))) + 1e-6
for idx, m in enumerate(members):
    i, j = int(m[0]), int(m[1])
    force = float(member_forces[idx])
    # Color: blue for compression, red for tension.
    intensity = min(abs(force) / max_force, 1.0)
    if force > 0:
        color = f"rgba(220, {int(80 + 175 * (1 - intensity))}, {int(80 + 175 * (1 - intensity))}, 1)"
    else:
        color = f"rgba({int(80 + 175 * (1 - intensity))}, {int(80 + 175 * (1 - intensity))}, 220, 1)"

    fig.add_trace(
        go.Scatter(
            x=[float(scaled_deformed[i, 0]), float(scaled_deformed[j, 0])],
            y=[float(scaled_deformed[i, 1]), float(scaled_deformed[j, 1])],
            mode="lines",
            line=dict(color=color, width=5),
            showlegend=False,
        )
    )

# Nodes.
fig.add_trace(
    go.Scatter(
        x=[float(p) for p in scaled_deformed[:, 0]],
        y=[float(p) for p in scaled_deformed[:, 1]],
        mode="markers+text",
        marker=dict(size=10, color="steelblue"),
        text=[str(i) for i in range(num_nodes)],
        textposition="top center",
        textfont=dict(size=9),
        showlegend=False,
    )
)

# Load arrow at load node (pointing downward from below)
fig.add_annotation(
    x=float(scaled_deformed[load_node_id, 0]),
    y=float(scaled_deformed[load_node_id, 1]) - 0.8,
    ax=0,
    ay=40,
    xref="x",
    yref="y",
    axref="pixel",
    ayref="pixel",
    showarrow=True,
    arrowhead=2,
    arrowsize=1.5,
    arrowwidth=3,
    arrowcolor="red",
)
fig.add_annotation(
    x=float(scaled_deformed[load_node_id, 0]),
    y=float(scaled_deformed[load_node_id, 1]) - 1.3,
    text="Load",
    showarrow=False,
    font=dict(size=12, color="red"),
)

fig.update_layout(
    title=f"Warren Truss Bridge Analysis (displacements x{scale})",
    xaxis=dict(title="x [m]", scaleanchor="y", scaleratio=1),
    yaxis=dict(title="y [m]"),
    height=400,
    showlegend=False,
    margin=dict(t=80, b=50, l=50, r=50),
)

# Add color legend.
fig.add_annotation(
    x=0.02,
    y=0.98,
    xref="paper",
    yref="paper",
    text="Red = Tension, Blue = Compression",
    showarrow=False,
    font=dict(size=10),
    align="left",
    bgcolor="white",
    bordercolor="gray",
    borderwidth=1,
)

HTML(fig.to_html(full_html=False, include_plotlyjs="cdn"))
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="89713a0e-d8d7-44b8-a263-d0c8e5e16d95" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("89713a0e-d8d7-44b8-a263-d0c8e5e16d95")) {                    Plotly.newPlot(                        "89713a0e-d8d7-44b8-a263-d0c8e5e16d95",                        [{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[0.0,3.0],"y":[0.0,0.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[3.0,6.0],"y":[0.0,0.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[6.0,9.0],"y":[0.0,0.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[9.0,12.0],"y":[0.0,0.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[1.5,4.5],"y":[2.0,2.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[4.5,7.5],"y":[2.0,2.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[7.5,10.5],"y":[2.0,2.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[0.0,1.5],"y":[0.0,2.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[1.5,3.0],"y":[2.0,0.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[3.0,4.5],"y":[0.0,2.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[4.5,6.0],"y":[2.0,0.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[6.0,7.5],"y":[0.0,2.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[7.5,9.0],"y":[2.0,0.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[9.0,10.5],"y":[0.0,2.0],"type":"scatter"},{"line":{"color":"lightgray","width":6},"mode":"lines","showlegend":false,"x":[10.5,12.0],"y":[2.0,0.0],"type":"scatter"},{"line":{"color":"rgba(211, 211, 220, 1)","width":5},"mode":"lines","showlegend":false,"x":[-6.402192866516998e-6,2.976957082748413],"y":[-6.325667072815122e-6,-0.2347564846277237],"type":"scatter"},{"line":{"color":"rgba(220, 210, 210, 1)","width":5},"mode":"lines","showlegend":false,"x":[2.976957082748413,6.0],"y":[-0.2347564846277237,-0.3999868631362915],"type":"scatter"},{"line":{"color":"rgba(220, 210, 210, 1)","width":5},"mode":"lines","showlegend":false,"x":[6.0,9.023040771484375],"y":[-0.3999868631362915,-0.23475788533687592],"type":"scatter"},{"line":{"color":"rgba(211, 211, 220, 1)","width":5},"mode":"lines","showlegend":false,"x":[9.023040771484375,12.000006675720215],"y":[-0.23475788533687592,-3.9272472349694e-6],"type":"scatter"},{"line":{"color":"rgba(167, 167, 220, 1)","width":5},"mode":"lines","showlegend":false,"x":[1.5919585227966309,4.545740127563477],"y":[1.8909542560577393,1.6737226247787476],"type":"scatter"},{"line":{"color":"rgba(80, 80, 220, 1)","width":5},"mode":"lines","showlegend":false,"x":[4.545740127563477,7.454262733459473],"y":[1.6737226247787476,1.6737236976623535],"type":"scatter"},{"line":{"color":"rgba(167, 167, 220, 1)","width":5},"mode":"lines","showlegend":false,"x":[7.454262733459473,10.408040046691895],"y":[1.6737236976623535,1.8909565210342407],"type":"scatter"},{"line":{"color":"rgba(181, 181, 220, 1)","width":5},"mode":"lines","showlegend":false,"x":[-6.402192866516998e-6,1.5919585227966309],"y":[-6.325667072815122e-6,1.8909542560577393],"type":"scatter"},{"line":{"color":"rgba(220, 181, 181, 1)"," ...

# %% [markdown]
# The solver found the equilibrium configuration of the Warren truss bridge under a prescribed displacement:
#
# - Deformed shape: Shown with exaggerated displacements for visibility
# - Member colors: Red indicates tension, blue indicates compression
#
# Key observations:
# - Bottom chord is in tension (red) - it resists the spreading of the supports
# - Top chord is in compression (blue) - it's being squeezed as the bridge sags
# - Diagonal members alternate between tension and compression
# - Maximum deflection occurs at the center where the load is applied
#
# This is the classic behavior of a simply-supported truss bridge under a center point load.

# %% [markdown]
# ## Varying displacements
#
# We can animate the truss response to different prescribed displacements. As the displacement increases,
# the internal forces grow proportionally (since we're in the linear elastic regime).
#
# Using `jax.vmap`, we solve for all displacement magnitudes in parallel.

# %%
# Solve for multiple displacement magnitudes using vmap.
displacement_magnitudes = jnp.linspace(0, 0.05, 21)  # 0 to 50 mm.


def solve_for_displacement(disp_y: jax.Array) -> jax.Array:
    """Solve truss for a given prescribed vertical displacement."""
    target_disp = jnp.array([0.0, -disp_y])
    costs_d: list[jaxls.Cost] = [
        bar_strain_energy(
            NodeVar(id=members[:, 0]),
            NodeVar(id=members[:, 1]),
            node_positions[members[:, 0]],
            node_positions[members[:, 1]],
            EA,
        ),
        pin_support(NodeVar(id=left_pin)),
        pin_support(NodeVar(id=right_pin)),
        prescribed_displacement(NodeVar(id=load_node_id), target_disp),
    ]
    problem_d = jaxls.LeastSquaresProblem(costs_d, [node_vars]).analyze()
    sol = problem_d.solve(verbose=False)
    return sol[node_vars]


# Use vmap to solve for all displacement values in parallel.
all_displacements = jax.vmap(solve_for_displacement)(displacement_magnitudes)
print(
    f"Solved for {len(displacement_magnitudes)} displacement values in parallel using vmap"
)
# Out:
# INFO     | Building optimization problem with 18 terms and 9 variables: 15 costs, 3 eq_zero, 0 leq_zero, 0 geq_zero
# INFO     | Vectorizing constraint group with 2 constraints (constraint_eq_zero), 1 variables each: augmented_pin_support
# INFO     | Vectorizing constraint group with 1 constraints (constraint_eq_zero), 1 variables each: augmented_prescribed_displacement
# INFO     | Vectorizing group with 15 costs, 2 variables each: bar_strain_energy
# Solved for 21 displacement values in parallel using vmap

# %%
# Create animated visualization with force coloring.
scale_anim = 10  # Displacement magnification


def get_member_color(force: float, max_force: float) -> str:
    """Get color for a member based on its force (red=tension, blue=compression)."""
    intensity = min(abs(force) / (max_force + 1e-6), 1.0)
    if force > 0:  # Tension
        return f"rgba(220, {int(80 + 175 * (1 - intensity))}, {int(80 + 175 * (1 - intensity))}, 1)"
    else:  # Compression
        return f"rgba({int(80 + 175 * (1 - intensity))}, {int(80 + 175 * (1 - intensity))}, 220, 1)"


# Compute member forces for all displacement configurations.
def compute_forces_for_disp(disp: jax.Array) -> jax.Array:
    """Compute all member forces for a given displacement field."""
    return jax.vmap(lambda m: compute_member_force(m[0], m[1], disp))(members)


all_forces = jax.vmap(compute_forces_for_disp)(all_displacements)
global_max_force = float(jnp.max(jnp.abs(all_forces)))

# Build frames for animation.
frames = []
for i, (disp_mag, disp, forces) in enumerate(
    zip(displacement_magnitudes, all_displacements, all_forces)
):
    scaled_pos = node_positions + scale_anim * disp

    # Create individual traces for each member (for per-member coloring)
    member_traces = []
    for idx, m in enumerate(members):
        mi, mj = int(m[0]), int(m[1])
        color = get_member_color(float(forces[idx]), global_max_force)
        member_traces.append(
            go.Scatter(
                x=[float(scaled_pos[mi, 0]), float(scaled_pos[mj, 0])],
                y=[float(scaled_pos[mi, 1]), float(scaled_pos[mj, 1])],
                mode="lines",
                line=dict(color=color, width=4),
                showlegend=False,
            )
        )

    # Node markers.
    node_trace = go.Scatter(
        x=[float(p) for p in scaled_pos[:, 0]],
        y=[float(p) for p in scaled_pos[:, 1]],
        mode="markers",
        marker=dict(size=8, color="steelblue"),
        showlegend=False,
    )

    deflection = float(-disp[load_node_id, 1]) * 1000
    frames.append(
        go.Frame(
            data=member_traces + [node_trace],
            name=str(i),
            layout=go.Layout(
                title=f"Prescribed Displacement: {float(disp_mag) * 1000:.1f} mm, "
                f"Actual: {deflection:.1f} mm"
            ),
        )
    )

# Initial frame data (first displacement = 0, so all gray)
init_pos = node_positions + scale_anim * all_displacements[0]
init_forces = all_forces[0]

init_traces = []
for idx, m in enumerate(members):
    mi, mj = int(m[0]), int(m[1])
    color = get_member_color(float(init_forces[idx]), global_max_force)
    init_traces.append(
        go.Scatter(
            x=[float(init_pos[mi, 0]), float(init_pos[mj, 0])],
            y=[float(init_pos[mi, 1]), float(init_pos[mj, 1])],
            mode="lines",
            line=dict(color=color, width=4),
            showlegend=False,
        )
    )

init_traces.append(
    go.Scatter(
        x=[float(p) for p in init_pos[:, 0]],
        y=[float(p) for p in init_pos[:, 1]],
        mode="markers",
        marker=dict(size=8, color="steelblue"),
        showlegend=False,
    )
)

fig_anim = go.Figure(
    data=init_traces,
    frames=frames,
    layout=go.Layout(
        title="Prescribed Displacement: 0.0 mm, Actual: 0.0 mm",
        xaxis=dict(title="x [m]", range=[-1, span + 1], scaleanchor="y", scaleratio=1),
        yaxis=dict(title="y [m]", range=[-1, height + 2]),
        height=450,
        margin=dict(b=100),
        updatemenus=[
            dict(
                type="buttons",
                showactive=False,
                y=0,
                x=0.1,
                xanchor="right",
                buttons=[
                    dict(
                        label="Play",
                        method="animate",
                        args=[
                            None,
                            dict(
                                frame=dict(duration=100, redraw=True), fromcurrent=True
                            ),
                        ],
                    ),
                    dict(
                        label="Pause",
                        method="animate",
                        args=[
                            [None],
                            dict(
                                frame=dict(duration=0, redraw=False), mode="immediate"
                            ),
                        ],
                    ),
                ],
            )
        ],
        sliders=[
            dict(
                active=0,
                steps=[
                    dict(
                        args=[
                            [str(i)],
                            dict(frame=dict(duration=0, redraw=True), mode="immediate"),
                        ],
                        label=f"{float(d) * 1000:.0f}",
                        method="animate",
                    )
                    for i, d in enumerate(displacement_magnitudes)
                ],
                x=0.1,
                len=0.8,
                xanchor="left",
                y=-0.15,
                currentvalue=dict(
                    prefix="Displacement (mm): ", visible=True, xanchor="center"
                ),
                transition=dict(duration=0),
            )
        ],
    ),
)

# Add color legend.
fig_anim.add_annotation(
    x=0.02,
    y=0.98,
    xref="paper",
    yref="paper",
    text="Red = Tension, Blue = Compression",
    showarrow=False,
    font=dict(size=10),
    align="left",
    bgcolor="white",
    bordercolor="gray",
    borderwidth=1,
)

HTML(fig_anim.to_html(full_html=False, include_plotlyjs="cdn", auto_play=False))
